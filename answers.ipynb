# %% [markdown]
# # Answers

# %% [markdown]
# Here you will find answers to the questions asked in `exercises.ipynb`. If you didn't succeed in answering a question, don't be sad. Learning programming is a lot about trying things out, and failing. It is important to learn from your mistakes, and try again. If you are stuck, you can always ask for help.

# %% [markdown]
# ## Part 1: What is Python, and what can it do?

# %% [markdown]
# Exercise 1: Install Anaconda Distribution
#
# Follow the instructions from this [repo](https://github.com/mikhailsirenko/python-101) to install Anaconda Distribution.

# %% [markdown]
# Exercise 2: Write your first Python program
#
# Open up terminal and run the following command:
#
# ```python
# print("Hello, World!)
# ```
#
# Tada, you're a programmer now!

# %% [markdown]
# ## Part 2: Operators and conditional statements

# %% [markdown]
# Exercise 3: Who likes 🍕?
#
# Create variables for your name (`str`), age (`int`), height (`float`), and a boolean value indicating whether you like pizza (`bool`). Then, print a sentence using these variables.

# %%
name = "Gandalf"
age = 999
height = 7.11
likes_pizza = True

print(f"My name is {name}, I am {age} years old, my height is {height} feet, and I like pizza: {likes_pizza}.")
# Out:
# My name is Gandalf, I am 999 years old, my height is 7.11 feet, and I like pizza: True.

# %% [markdown]
# Exercise 4: Rock, Paper, Scissors 🗿📄✂️
#
# Write a program that takes two users input and compares them. If the two inputs are the same, print "It's a tie!". If the two inputs are different, print "Player 1 wins!" or "Player 2 wins!" depending on which input is larger.

# %%
player1 = input("Player 1, enter your choice (rock, paper, scissors): ")
player2 = input("Player 2, enter your choice (rock, paper, scissors): ")

if player1 == player2:
    print("It's a tie!")
elif (player1 == "rock" and player2 == "scissors") or (player1 == "paper" and player2 == "rock") or (player1 == "scissors" and player2 == "paper"):
    print("Player 1 wins!")
elif (player2 == "rock" and player1 == "scissors") or (player2 == "paper" and player1 == "rock") or (player2 == "scissors" and player1 == "paper"):
    print("Player 2 wins!")
else:
    print("Invalid input!")

# %% [markdown]
# ## Part 3: Loops and data structures

# %% [markdown]
# Exercise 5: Sum of Numbers ➕
#
# Write a program that asks the user for a number and then prints the sum of all the integers from 1 to that number.

# %%
n = int(input("Enter a positive integer: "))
sum_of_numbers = 0

for i in range(1, n+1):
    sum_of_numbers += i

print(f"Sum of numbers from 1 to {n}: {sum_of_numbers}")

# %% [markdown]
# Exercise 6: Dictionary Lookup 🔍
#
# Write a program that takes this dictionary as input and then asks the user to enter a name. If a name is found in the dictionary, the program should print the corresponding phone number. If not, the program should print a message saying that the name is not found.
#
#
# ```python
# phonebook = {
#     "Alice": "555-1234",
#     "Bob": "555-5678",
#     "Charlie": "555-2468"
# }
# ```

# %%
phonebook = {
    "Alice": "555-1234",
    "Bob": "555-5678",
    "Charlie": "555-2468"
}

name = input("Enter a name: ")

if name in phonebook:
    print(f"{name}'s phone number is {phonebook[name]}.")
else:
    print(f"{name} not found in the phonebook.")
# Out:
# Bob's phone number is 555-5678.

# %% [markdown]
# ## Part 4: Graphs and extra

# %% [markdown]
# Exercise 7: Weekly Temperature Line Plot 🌡️
#
# Write a program that displays temperature by day of the week in a line plot.
#
# ```python
#
# days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
# temperatures = [72, 75, 78, 76, 71, 70, 69]
# ```

# %%
import matplotlib.pyplot as plt

days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
temperatures = [72, 75, 78, 76, 71, 70, 69]

plt.plot(days, temperatures, marker='o')
plt.xlabel('Days of the Week')
plt.ylabel('Temperature (Fahrenheit)')
plt.title('Weekly Temperature Fluctuations')
plt.show()
